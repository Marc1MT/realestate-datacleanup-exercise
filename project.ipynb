# %% [markdown]
# # Real Estate Clean up
#
# This is a real dataset and it was downloaded using web scraping techniques. The data contains registers from fotocasa which is one of the most popular websites of real estate in Spain. Please, do not do this (web scraping) unless it is for academic purposes.
#
# The dataset was downloaded a few years ago by Henry Navarro and In no case were economic returns obtained from it.
#
# It contains thousands of data from real houses published on the web www.fotocasa.com. Your goal is to extract as much information as possible with the knowledge you have so far about data science, for example what is the most expensive house in the entire dataset?
#
# Let's start with precisely that question... Good luck!

# %% [markdown]
# #### Exercise 00. Read the dataset assets/real_estate.csv and try to visualize the table (★☆☆)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# this CSV file contains semicolons instead of comas as separator
ds = pd.read_csv('assets/real_estate.csv', sep=';')
ds
# Out:
#        Unnamed: 0  id_realEstates  isNew                    realEstate_name  \
# 0               1       153771986  False            ferrari 57 inmobiliaria
# 1               2       153867863  False  tecnocasa fuenlabrada ferrocarril
# 2               3       153430440  False                 look find boadilla
# 3               4       152776331  False  tecnocasa fuenlabrada ferrocarril
# 4               5       153180188  False            ferrari 57 inmobiliaria
# ...           ...             ...    ...                                ...
# 15330       15331       153901377  False                infocasa consulting
# 15331       15332       150394373  False                inmobiliaria pulpon
# 15332       15333       153901397  False             tecnocasa torrelodones
# 15333       15334       152607440  False                inmobiliaria pulpon
# 15334       15335       153901356  False                infocasa consulting
#
#        phone_realEstate                                       url_inmueble  \
# 0           912177526.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 1           916358736.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 2           916350408.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 3           916358736.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 4           912177526.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# ...                 ...                                                ...
# 15330       911360461.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 15331       912788039.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 15332       912780348.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 15333       912788039.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 15334       911360461.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
#
#        rooms  bathrooms  surface   price  ... level4Id level5Id level6Id  \
# 0        3.0        2.0    103.0  195000  ...        0        0        0
# 1        3.0        1.0      NaN   89000  ...        0        0        0
# 2        2.0        2.0     99.0  390000  ...        0        0        0
# 3        3.0        1.0     86.0   89000  ...        0        0        0
# 4        2.0        2.0    106.0  172000  ...        0        0        0
# ...      ...        ...      ...     ...  ...      ...      ...      ...
# 15330    2.0        1.0     96.0  259470  ...        0        0        0
# 15331    3.0        1.0    150.0  165000  ...        0        0        0
# 15332    4.0        2.0    175.0  495000  ...        0        0        0
# 15333    3.0        2.0    101.0  195000  ...        0        0        0
# 15334    3.0        2.0    152.0  765000  ...        0        0        0
#
#       level7Id level8Id accuracy          latitude          longitude zipCode  \
# 0            0        0        0  40,2948276786438  -3,44402412135624     NaN
# 1            0        0        1          40,28674           -3,79351     NaN
# 2            0        0        0  40,4115646786438  -3,90662252135624     NaN
# 3            0        0        0  40,2853785786438  -3,79508142135624     NaN
# 4            0        0        0  40,2998774864376  -3,45226301356237     NaN
# ...        ...      ...      ...               ...                ...     ...
# 15330        0        0        0          40,45416           -3,70286     NaN
# 15331        0        0        0          40,36652           -3,48951     NaN
# 15332        0        0        0          40,57444           -3,92124     NaN
# 15333        0        0        0          40,36967           -3,48105     NaN
# 15334        0        0        0          40,45773           -3,69068     NaN
#
#       customZone
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 15330        NaN
# 15331        NaN
# 15332        NaN
# 15333        NaN
# 15334        NaN
#
# [15335 rows x 37 columns]

# %% [markdown]
# #### Exercise 01. Which is the most expensive house in the dataset? (★☆☆)
#
# Print the address and the price of the selected house. For example:
#
# `The house with address General Street Nº5 is the most expensive and its price is 5000000 USD`

# %%
# Import panda
import pandas as pd
# Find the row with the most expensive House
most_expensive = ds[ds['price'] == ds['price'].max()]

# Extract the adress and price of the most expensive House
address = most_expensive['address'].values[0]
price = most_expensive['price'].values[0]

#print result
print(f"The house with address {address} is the most expensive and its price is {price} USD")
# Out:
# The house with address El Escorial is the most expensive and its price is 8500000 USD

# %% [markdown]
# #### Exercise 02. Which is cheapest house in the dataset? (★☆☆)
#
# Print the address and the price of the selected house. For example:
#
# `The house with address Concrete Street Nº1 is the cheapest and its price is 12000 USD`

# %%
# Find the row with the cheapest House
cheapest = ds[ds['price'] == ds['price'].min()]

# Extract the adress and price of the most expensive House
address = cheapest['address'].values[0]
price = cheapest['price'].values[0]

#print result
print(f"The house with address {address} is the cheapest and its price is {price} USD")
# Out:
# The house with address Parla is the cheapest and its price is 0 USD

# %% [markdown]
# #### Exercise 03. Which is the biggest and the smallest house in the dataset? (★☆☆)
#
# Print both the address and the surface of the selected houses. For example:
#
# `The bigger house is located on Yukka Street Nº10 and its surface is 5000 meters`
#
# `The smaller house is located on County Road 1 N and its surface is 200 meters`

# %%
import pandas as pd

# Find the row with the largest surface
biggest_house = ds[ds['surface'] == ds['surface'].max()]

# Find the row with the smallest surface
smallest_house = ds[ds['surface'] == ds['surface'].min()]

# Extract the address and surface of the biggest house
biggest_address = biggest_house['address'].values[0]
biggest_surface = biggest_house['surface'].values[0]

# Extract the address and surface of the smallest house
smallest_address = smallest_house['address'].values[0]
smallest_surface = smallest_house['surface'].values[0]

# Print the results
print(f"The bigger house is located on {biggest_address} and its surface is {biggest_surface} meters")
print(f"The smaller house is located on {smallest_address} and its surface is {smallest_surface} meters")
# Out:
# The bigger house is located on Sevilla la Nueva and its surface is 249000.0 meters
# The smaller house is located on Calle Amparo,  Madrid Capital and its surface is 15.0 meters

# %% [markdown]
# #### Exercise 04. How many populations (level5 column) the dataset contains? (★☆☆)
#
# Print the name of the populations with comma as separator. For example:
#
# `> print(populations)`
#
# `population1, population2, population3,...`

# %%
# Get unique values in the 'level5' column
populations = ds['level5'].unique()

# Convert the unique values to a comma-separated string
populations_str = ', '.join(populations)

# Print the result
print(populations_str)
# Out:
# Arganda del Rey, Fuenlabrada, Boadilla del Monte, Las Rozas de Madrid,  Madrid Capital, Villaviciosa de Odón, Pinto, Valdemoro, Navalcarnero, Pozuelo de Alarcón, Torrejón de Ardoz, Navalagamella, San Sebastián de los Reyes, Rivas-vaciamadrid, Alpedrete, Móstoles, San Fernando de Henares, Coslada, Becerril de la Sierra, Alcalá de Henares, Chinchón, Parla, Alcorcón, El Escorial, Leganés, Pedrezuela, Majadahonda, Villanueva de la Cañada, Villanueva del Pardillo, Torrelodones, Moralzarzal, Mejorada del Campo, Aranjuez, Corpa, Getafe, Velilla de San Antonio, Sevilla la Nueva, San Martín de la Vega, Villalbilla, Collado Villalba, Alcobendas, El Molar (Madrid), Moraleja de Enmedio, Algete, Campo Real, Torrejón de la Calzada, Colmenar Viejo, Valdemorillo, Fuente El Saz de Jarama, Tres Cantos, Arroyomolinos (Madrid), Griñón, Paracuellos de Jarama, Guadarrama, Titulcia, Galapagar, Collado Mediano, Los Molinos, San Lorenzo de El Escorial, Loeches, San Martín de Valdeiglesias, Navas del Rey, Bustarviejo, Manzanares El Real, Carabaña, Casarrubuelos, Cercedilla, Fresnedillas de la Oliva, Valdemaqueda, Robledo de Chavela, Miraflores de la Sierra, Humanes de Madrid, Valdetorres de Jarama, San Agustín del Guadalix, Ciempozuelos, Camarma de Esteruelas, Torres de la Alameda, Talamanca de Jarama, El Atazar, Hoyo de Manzanares, El Boalo - Cerceda – Mataelpino, El Álamo, Valdilecha, Valdeolmos-Alalpardo, Guadalix de la Sierra, Belmonte de Tajo, El Vellón, Brunete, Redueña, Morata de Tajuña, Tielmes, Gargantilla del Lozoya, Meco, Venturada, Quijorna, Cenicientos, Torrejón de Velasco, Navacerrada, Santa María de la Alameda, Orusco de Tajuña, Daganzo de Arriba, Villamanta, Anchuelo, Valdaracete, Ajalvir, Los Santos de la Humosa, Villamanrique de Tajo, Colmenar de Oreja, Villa del Prado, Fuentidueña de Tajo, Colmenar del Arroyo, Valdelaguna, Cubas de la Sagra, Valdeavero, Aldea del Fresno, Ribatejada, Torrelaguna, Batres, Pezuela de las Torres, Colmenarejo, Serranillos del Valle, Cobeña, Soto del Real, El Berrueco, Villanueva de Perales, Fresno de Torote - Serracines, Pozuelo del Rey, Pelayos de la Presa, La Cabrera, Nuevo Baztán, Perales de Tajuña, Villaconejos, Villarejo de Salvanés, Cadalso de los Vidrios, Santorcaz, Madarcos, Garganta de los Montes, Puentes Viejas, Torremocha de Jarama, Valdemanco, Braojos, Lozoyuela-navas-sieteiglesias, Piñuécar-gandullas, Valdepiélagos, Valverde de Alcalá, Villar del Olmo, Villamantilla, Horcajo de la Sierra, Gascones, Zarzalejo, Villavieja del Lozoya, Brea de Tajo, Estremera, Chapinería, Navarredonda, Patones, Ambite, Navalafuente, Lozoya, Canencia, Cabanillas de la Sierra, Buitrago del Lozoya, Fresno de Torote, Robregordo, Pinilla del Valle, Rascafría, La Hiruela, Montejo de la Sierra

# %% [markdown]
# #### Exercise 05. Does the dataset contain NAs? (★☆☆)
#
# Print a boolean value (`true` or `fase`) followed by the rows/cols that contains NAs.

# %%
# Check if the dataset contains NAs
contains_nas = ds.isna().any().any()

# If the dataset contains NAs, print the boolean value and the rows/columns with NAs
if contains_nas:
    print(True)
      # Print rows with NAs
    rows_with_nas = ds[ds.isna().any(axis=1)]
    print("Rows with NAs:")
    print(rows_with_nas)
    # Print columns with NAs
    cols_with_nas = ds.columns[ds.isna().any()].tolist()
    print("Columns with NAs:", cols_with_nas)

else:
    print(False)
# Out:
# True
# Rows with NAs:
#        Unnamed: 0  id_realEstates  isNew                    realEstate_name  \
# 0               1       153771986  False            ferrari 57 inmobiliaria
# 1               2       153867863  False  tecnocasa fuenlabrada ferrocarril
# 2               3       153430440  False                 look find boadilla
# 3               4       152776331  False  tecnocasa fuenlabrada ferrocarril
# 4               5       153180188  False            ferrari 57 inmobiliaria
# ...           ...             ...    ...                                ...
# 15330       15331       153901377  False                infocasa consulting
# 15331       15332       150394373  False                inmobiliaria pulpon
# 15332       15333       153901397  False             tecnocasa torrelodones
# 15333       15334       152607440  False                inmobiliaria pulpon
# 15334       15335       153901356  False                infocasa consulting
#
#        phone_realEstate                                       url_inmueble  \
# 0           912177526.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 1           916358736.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 2           916350408.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 3           916358736.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 4           912177526.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# ...                 ...                                                ...
# 15330       911360461.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 15331       912788039.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 15332       912780348.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 15333       912788039.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 15334       911360461.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
#
#        rooms  bathrooms  surface   price  ... level4Id level5Id level6Id  \
# 0        3.0        2.0    103.0  195000  ...        0        0        0
# 1        3.0        1.0      NaN   89000  ...        0        0        0
# 2        2.0        2.0     99.0  390000  ...        0        0        0
# 3        3.0        1.0     86.0   89000  ...        0        0        0
# 4        2.0        2.0    106.0  172000  ...        0        0        0
# ...      ...        ...      ...     ...  ...      ...      ...      ...
# 15330    2.0        1.0     96.0  259470  ...        0        0        0
# 15331    3.0        1.0    150.0  165000  ...        0        0        0
# 15332    4.0        2.0    175.0  495000  ...        0        0        0
# 15333    3.0        2.0    101.0  195000  ...        0        0        0
# 15334    3.0        2.0    152.0  765000  ...        0        0        0
#
#       level7Id level8Id accuracy          latitude          longitude zipCode  \
# 0            0        0        0  40,2948276786438  -3,44402412135624     NaN
# 1            0        0        1          40,28674           -3,79351     NaN
# 2            0        0        0  40,4115646786438  -3,90662252135624     NaN
# 3            0        0        0  40,2853785786438  -3,79508142135624     NaN
# 4            0        0        0  40,2998774864376  -3,45226301356237     NaN
# ...        ...      ...      ...               ...                ...     ...
# 15330        0        0        0          40,45416           -3,70286     NaN
# 15331        0        0        0          40,36652           -3,48951     NaN
# 15332        0        0        0          40,57444           -3,92124     NaN
# 15333        0        0        0          40,36967           -3,48105     NaN
# 15334        0        0        0          40,45773           -3,69068     NaN
#
#       customZone
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 15330        NaN
# 15331        NaN
# 15332        NaN
# 15333        NaN
# 15334        NaN
#
# [15335 rows x 37 columns]
# Columns with NAs: ['realEstate_name', 'phone_realEstate', 'rooms', 'bathrooms', 'surface', 'description', 'level4', 'level6', 'level7', 'level8', 'zipCode', 'customZone']

# %% [markdown]
# #### Exercise 06. Delete the NAs of the dataset, if applicable (★★☆)
#
# Print a comparison between the dimensions of the original DataFrame versus the DataFrame after the deletions

# %%
# Get the dimensions of the original DataFrame
original_shape = ds.shape

# Drop rows containing NAs and create a new DataFrame without them
ds_cleaned = ds.dropna()

# Get the dimensions of the cleaned DataFrame
cleaned_shape = ds_cleaned.shape

print("Original DataFrame Dimensions:", original_shape)
print("Cleaned DataFrame Dimensions:", cleaned_shape)
# Out:
# Original DataFrame Dimensions: (15335, 37)
# Cleaned DataFrame Dimensions: (0, 37)

# %% [markdown]
# #### Exercise 07. Which is the mean of prices in the population (level5 column) of "Arroyomolinos (Madrid)"? (★★☆)
#
# Print the obtained value

# %%
# Filter the DataFrame to select rows where 'level5' is equal to "Arroyomolinos (Madrid)"
arroyomolinos = ds[ds['level5'] == 'Arroyomolinos (Madrid)']

# Calculate the mean price for this population
mean_price = arroyomolinos['price'].mean()

# Print the mean price
print(mean_price)
# Out:
# 294541.59854014596

# %% [markdown]
# #### Exercise 08. Plot the histogram of prices for the population (level5 column) of "Arroyomolinos (Madrid)" and explain what you observe (★★☆)
#
# Print the histogram of the prices and write in the Markdown cell a brief analysis about the plot.

# %%
# Import matplotlib
import matplotlib.pyplot as plt

# Filter the DataFrame to select rows where 'level5' is equal to "Arroyomolinos (Madrid)"
arroyomolinos = ds[(ds['level5'] == 'Arroyomolinos (Madrid)') & (ds['price'] > 0)]

# Create a histogram of prices
plt.hist(arroyomolinos['price'], bins=10, color='blue', edgecolor='black')

# Add labels and a title to the plot
plt.xlabel('price (€)')
plt.ylabel('Frequency')
plt.title('Histogram of Prices in Arroyomolinos (Madrid)')

# Show the plot
plt.show()

# %% [markdown]
# **TODO: Markdown**. To write here, double click to this cell and just remove this content and place the text you want to write. Then, execute the cell.

# %% [markdown]
# #### Exercise 09. Is the average of "Valdemorillo" and "Galapagar" prices the same? (★★☆)
#
# Print the both average prices and then write a conclusion about them

# %%
#Filter the DataFrame to select rows where 'level5' is equal to "Valdemorillo" and calculate the average price
valdemorillo_avg_price = ds[ds['level5'] == 'Valdemorillo']['price'].mean()

# Filter the DataFrame to select rows where 'level5' is equal to "Galapagar" and calculate the average price
galapagar_avg_price = ds[ds['level5'] == 'Galapagar']['price'].mean()

# Print the average prices
print(f"Average Price in Valdemorillo: {valdemorillo_avg_price}")
print(f"Average Price in Galapagar: {galapagar_avg_price}")

# Compare the average prices and draw a conclusion
if valdemorillo_avg_price == galapagar_avg_price:
    print("The average prices in Valdemorillo and Galapagar are the same.")
else:
    if valdemorillo_avg_price > galapagar_avg_price:
        print("The average price in Valdemorillo is higher than in Galapagar.")
    else:
        print("The average price in Galapagar is higher than in Valdemorillo.")
# Out:
# Average Price in Valdemorillo: 363860.2931034483
# Average Price in Galapagar: 360063.20238095237
# The average price in Valdemorillo is higher than in Galapagar.

# %% [markdown]
# #### Exercise 10. Is the average of "Valdemorillo" and "Galapagar" price per square meter (price/m2) the same? (★★☆)
#
# Print the both average prices and then write a conclusion about
#
# Hint: Create a new column called `pps` (price per square) and then analyse the values

# %%
# Filter the DataFrame to select rows where 'level5' is equal to "Valdemorillo" and "Galapagar"
valdemorillo_df = ds[ds['level5'] == 'Valdemorillo']
galapagar_df = ds[ds['level5'] == 'Galapagar']

# Calculate the price per square meter (pps) for each population and add it as a new column
valdemorillo_df['pps'] = valdemorillo_df['price'] / valdemorillo_df['surface']
galapagar_df['pps'] = galapagar_df['price'] / galapagar_df['surface']

# Calculate the average price per square meter for each population
average_pps_valdemorillo = valdemorillo_df['pps'].mean()
average_pps_galapagar = galapagar_df['pps'].mean()

# Print the average prices per square meter
print("Average Price per Square Meter in Valdemorillo:", average_pps_valdemorillo)
print("Average Price per Square Meter in Galapagar:", average_pps_galapagar)

# Compare the average prices per square meter and draw a conclusion
if average_pps_valdemorillo == average_pps_galapagar:
    print("The average price per square meter in Valdemorillo and Galapagar is the same.")
elif average_pps_valdemorillo > average_pps_galapagar:
    print("Valdemorillo has a higher price per meter square.")
else:
    print("Galapagar has a higher price per meter square.")
# Out:
# Average Price per Square Meter in Valdemorillo: 1317.9502109024986
# Average Price per Square Meter in Galapagar: 1606.3240303094024
# Galapagar has a higher price per meter square.
# /tmp/ipykernel_2212/1361497138.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valdemorillo_df['pps'] = valdemorillo_df['price'] / valdemorillo_df['surface']
# /tmp/ipykernel_2212/1361497138.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   galapagar_df['pps'] = galapagar_df['price'] / galapagar_df['surface']

# %% [markdown]
# #### Exercise 11. Analyse the relation between the surface and the price of the houses (★★☆)
#
# Hint: You can make a `scatter plot` and then write a conclusion about it

# %%
import matplotlib.pyplot as plt
import pandas as pd

ds_clean = ds[ds['price'] >0]

# Create a scatter plot of Surface vs. Price
plt.figure(figsize=(10, 12))
plt.scatter(ds_clean['surface'], ds_clean['price'], alpha=0.5)
plt.title('Scatter Plot of Surface vs. Price')
plt.xlabel('Surface (square meters)')
plt.ylabel('Price (USD)')
plt.grid(True)

#algo falla en el gráfico. No tiene sentido

# %% [markdown]
# **TODO: Markdown**. To write here, double click to this cell and just remove this content and place the text you want to write. Then, execute the cell.

# %% [markdown]
# #### Exercise 12. How many real estate agencies the dataset contains? (★★☆)
#
# Print the obtained value

# %%
# Find number of unique agencies
num_agencies = ds['realEstate_name'].nunique()

# Print the number of unique agencies
print("Number of Real Estate Agencies:", num_agencies)
# Out:
# Number of Real Estate Agencies: 1821

# %% [markdown]
# #### Exercise 13. Which is the population (level5 column) that contains the most houses? (★★☆)
#
# Print both the population and the number of houses

# %%
# Find number of houses in each population
population_counts = ds['level5'].value_counts()

# Find the population with the highest count
most_houses_population = population_counts.idxmax()
most_houses_count = population_counts.max()

# Print the population and the number of houses
print("Population with the Most Houses:",most_houses_population,",", "Number of Houses:", most_houses_count)
# Out:
# Population with the Most Houses:  Madrid Capital , Number of Houses: 6643

# %% [markdown]
# #### Exercise 14. Now let's work with the "south belt" of madrid. Make a subset of the original DataFrame that contains the following populations (level5 column): "Fuenlabrada","Leganés","Getafe","Alcorcón" (★★☆)
#
# Hint: Filter the original DataFrame using the column `level5` and the function `isin`

# %%
# Southbelt populations
south_belt = ["Fuenlabrada", "Leganés", "Getafe", "Alcorcón"]

# Create a subset DataFrame containing only the specified populations
south_belt_df = ds_clean[ds_clean['level5'].isin(south_belt)]
south_belt_df
# Out:
#        Unnamed: 0  id_realEstates  isNew  \
# 1               2       153867863  False
# 3               4       152776331  False
# 85             86       153152077  False
# 94             95       153995577  False
# 109           110       153586414  False
# ...           ...             ...    ...
# 15275       15276       153903887  False
# 15291       15292       151697757  False
# 15305       15306       153902389  False
# 15322       15323       153871864  False
# 15325       15326       153901467  False
#
#                                  realEstate_name  phone_realEstate  \
# 1              tecnocasa fuenlabrada ferrocarril       916358736.0
# 3              tecnocasa fuenlabrada ferrocarril       916358736.0
# 85                       sinergical inmobiliaria               NaN
# 94                               viviendas365com       911226014.0
# 109              area uno asesores inmobiliarios       912664081.0
# ...                                          ...               ...
# 15275  aliseda servicios de gestion inmobiliaria       911368198.0
# 15291                                    unipiso       912788631.0
# 15305                             jadein ferrero       914871639.0
# 15322                          gestion comercial       911220662.0
# 15325                              montehogar 68       911790675.0
#
#                                             url_inmueble  rooms  bathrooms  \
# 1      https://www.fotocasa.es/es/comprar/vivienda/ma...    3.0        1.0
# 3      https://www.fotocasa.es/es/comprar/vivienda/ma...    3.0        1.0
# 85     https://www.fotocasa.es/es/comprar/vivienda/le...    1.0        1.0
# 94     https://www.fotocasa.es/es/comprar/vivienda/le...    3.0        2.0
# 109    https://www.fotocasa.es/es/comprar/vivienda/ma...    3.0        3.0
# ...                                                  ...    ...        ...
# 15275  https://www.fotocasa.es/es/comprar/vivienda/al...    3.0        1.0
# 15291  https://www.fotocasa.es/es/comprar/vivienda/al...    3.0        2.0
# 15305  https://www.fotocasa.es/es/comprar/vivienda/ma...    3.0        2.0
# 15322  https://www.fotocasa.es/es/comprar/vivienda/ma...    3.0        1.0
# 15325  https://www.fotocasa.es/es/comprar/vivienda/ma...    2.0        2.0
#
#        surface   price  ... level4Id level5Id level6Id level7Id level8Id  \
# 1          NaN   89000  ...        0        0        0        0        0
# 3         86.0   89000  ...        0        0        0        0        0
# 85        50.0  107000  ...        0        0        0        0        0
# 94       120.0  320000  ...        0        0        0        0        0
# 109      142.0  425000  ...        0        0        0        0        0
# ...        ...     ...  ...      ...      ...      ...      ...      ...
# 15275     78.0  138000  ...        0        0        0        0        0
# 15291    110.0  279000  ...        0        0        0        0        0
# 15305     85.0  170000  ...        0        0        0        0        0
# 15322     91.0  112000  ...        0        0        0        0        0
# 15325     99.0  215000  ...        0        0        0        0        0
#
#       accuracy          latitude          longitude zipCode customZone
# 1            1          40,28674           -3,79351     NaN        NaN
# 3            0  40,2853785786438  -3,79508142135624     NaN        NaN
# 85           1          40,35059           -3,82693     NaN        NaN
# 94           0          40,31933           -3,77574     NaN        NaN
# 109          0        40,3313411         -3,8313868     NaN        NaN
# ...        ...               ...                ...     ...        ...
# 15275        1          40,31381           -3,83733     NaN        NaN
# 15291        0        40,3259051           -3,76318     NaN        NaN
# 15305        0        40,2882193         -3,8098617     NaN        NaN
# 15322        0          40,28282           -3,78892     NaN        NaN
# 15325        1          40,28062           -3,79869     NaN        NaN
#
# [895 rows x 37 columns]

# %% [markdown]
# #### Exercise 15. Make a bar plot of the median of the prices and explain what you observe (you must use the subset obtained in the question 14) (★★★)
#
# Print the bar of the median of the prices and write in the Markdown cell a brief analysis about the plot

# %%
import matplotlib.pyplot as plt

# Group the data by population and calculate the median price for each population
median_southbelt = south_belt_df.groupby('level5')['price'].median()

# Create a bar plot
plt.figure(figsize=(10, 6))
median_southbelt.plot(kind='bar', color='skyblue')
plt.title('Median Prices for South Belt Populations')
plt.xlabel('Population')
plt.ylabel('Median Price (USD)')
plt.xticks(rotation=45)
plt.grid(axis='y')


plt.show()

# %% [markdown]
# **TODO: Markdown**. To write here, double click to this cell and just remove this content and place the text you want to write. Then, execute the cell.

# %% [markdown]
# #### Exercise 16. Calculate the sample mean and variance of the variables: price, rooms, surface area and bathrooms (you must use the subset obtained in the question 14) (★★★)
#
# Print both values for each variable

# %%
# Calculate the sample mean and variance of each variable
mean_price = south_belt_df['price'].mean()
variance_price = south_belt_df['price'].var()

mean_rooms = south_belt_df['rooms'].mean()
variance_rooms = south_belt_df['rooms'].var()

mean_surface = south_belt_df['surface'].mean()
variance_surface = south_belt_df['surface'].var()

mean_bathrooms = south_belt_df['bathrooms'].mean()
variance_bathrooms = south_belt_df['bathrooms'].var()

# Print the calculated values
print("Sample Mean and Variance for Price:")
print("Mean Price:", mean_price)
print("Variance of Price:", variance_price)

print("\nSample Mean and Variance for Rooms:")
print("Mean Rooms:", mean_rooms)
print("Variance of Rooms:", variance_rooms)

print("\nSample Mean and Variance for Surface Area:")
print("Mean Surface Area:", mean_surface)
print("Variance of Surface Area:", variance_surface)

print("\nSample Mean and Variance for Bathrooms:")
print("Mean Bathrooms:", mean_bathrooms)
print("Variance of Bathrooms:", variance_bathrooms)
# Out:
# Sample Mean and Variance for Price:
# Mean Price: 226085.69162011173
# Variance of Price: 14444627877.728062
#
# Sample Mean and Variance for Rooms:
# Mean Rooms: 3.0235955056179775
# Variance of Rooms: 0.7204774964927139
#
# Sample Mean and Variance for Surface Area:
# Mean Surface Area: 111.29806451612903
# Variance of Surface Area: 4275.920086688338
#
# Sample Mean and Variance for Bathrooms:
# Mean Bathrooms: 1.6271186440677967
# Variance of Bathrooms: 0.5757343354551729

# %% [markdown]
# #### Exercise 17. What is the most expensive house of each population? You must use the subset obtained in the question 14 (★★☆)
#
# Print both the address and the price of the selected house of each population. You can print a DataFrame or a single line for each population

# %%
#Find the most expensive house of each population
Max_zona = ds.groupby("level5")["price"].max()
print(Max_zona)
# Out:
# level5
#  Madrid Capital          8000000
# Ajalvir                   345000
# Alcalá de Henares         850000
# Alcobendas               8000000
# Alcorcón                  950000
#                           ...
# Villar del Olmo           280000
# Villarejo de Salvanés     226000
# Villaviciosa de Odón     1900000
# Villavieja del Lozoya     260000
# Zarzalejo                 199000
# Name: price, Length: 168, dtype: int64

# %% [markdown]
# #### Exercise 18. Normalize the variable of prices for each population and plot the 4 histograms in the same plot (you must use the subset obtained in the question 14) (★★★)
#
# For the normalization method you can use the one you consider to, there is not a single correct answer to this question. Print the plot and write in the Markdown cell a brief analysis about the plot
#
# Hint: You can help yourself reviewing the multihist demo of Matplotlib

# %%
# south belt variable:
south_belt = ["Fuenlabrada", "Leganés", "Getafe", "Alcorcón"]

# Create a figure and axis for the plot
fig, ax = plt.subplots(figsize=(10, 6))

# Create a list to store the normalized prices for each population
normalized_prices = []

# Iterate through selected populations and normalize prices
for population in south_belt:
    population_data = south_belt_df[south_belt_df['level5'] == population]
    normalized_price = (population_data['price'] - population_data['price'].mean()) / population_data['price'].std()
    normalized_prices.append(normalized_price)

# Create a histogram
colors = ['red', 'blue', 'green', 'purple']
labels = south_belt

ax.hist(
    normalized_prices,
    bins=30,
    color=colors,
    label=labels,
    alpha=0.7,
    stacked=False,
    density=True
)

ax.set_xlabel('Normalized Price')
ax.set_ylabel('Frequency')
ax.set_title('Normalized Prices for each South Belt Population')
ax.legend()

# Show the plot
plt.show()

# %% [markdown]
# **TODO: Markdown**. To write here, double click to this cell and just remove this content and place the text you want to write. Then, execute the cell.

# %% [markdown]
# #### Exercise 19. What can you say about the price per square meter (price/m2) between the towns of "Getafe" and "Alcorcón"? You must use the subset obtained in the question 14 (★★☆)
#
# Hint: Create a new column called `pps` (price per square) and then analyse the values

# %%
# Create a new column 'pps' 
south_belt_df.loc[:, 'pps'] = south_belt_df['price'] / south_belt_df['surface']

# Filter the DataFrame to select data from Getafe & Alcorcón
getafe_df = south_belt_df[south_belt_df['level5'] == 'Getafe']
alcorcon_df = south_belt_df[south_belt_df['level5'] == 'Alcorcón']

# Calculate the mean pps
mean_pps_getafe = getafe_df['pps'].mean()
mean_pps_alcorcon = alcorcon_df['pps'].mean()

# Print the mean price per square meter for both towns
print("Mean pps in Getafe:", mean_pps_getafe)
print("Mean pps in Alcorcón:", mean_pps_alcorcon)
# Out:
# Mean pps in Getafe: 2174.5934618759934
# Mean pps in Alcorcón: 2239.302480199618

# %% [markdown]
# #### Exercise 20. Make the same plot for 4 different populations (level5 column) and rearrange them on the same graph? You must use the subset obtained in the question 14 (★★☆)
# Hint: make a scatter plot of each population using subplots.

# %%
import matplotlib.pyplot as plt
import numpy as np

# New and old population variable
new_populations = ["San Lorenzo de El Escorial", "Soto del Real", "Madrid Capital", "Pinto","Fuenlabrada", "Leganés", "Getafe", "Alcorcón"]

# Create a subset DataFrame containing only the specified populations
new_populations_df = ds_clean[ds_clean['level5'].isin(new_populations)]

# Create a figure and axis for the plot
fig, ax = plt.subplots(figsize=(20, 10))

# Create a list to store the normalized prices for each population
normalized_prices = []

# Colors for the histogram (add more colors if needed)
colors = ['red', 'blue', 'green', 'purple', 'orange', 'brown', 'black', 'gray']

# Iterate through the updated list of populations and normalize prices
for population in new_populations:
    population_data = new_populations_df[new_populations_df['level5'] == population]
    
    # Check for zero or near-zero standard deviation
    if np.isclose(population_data['price'].std(), 0):
        continue  # Skip this population

    normalized_price = (population_data['price'] - population_data['price'].mean()) / population_data['price'].std()
    normalized_prices.append(normalized_price)

# Create a histogram for each population
ax.hist(
    normalized_prices,
    bins=35,
    color=colors[:len(normalized_prices)],  # Use as many colors as there are valid populations
    label=[pop for pop in south_belt if not np.isclose(new_populations_df[new_populations_df['level5'] == pop]['price'].std(), 0)],
    alpha=0.7,
    stacked=False,
    density=True
)

# Set labels, title, and legend
ax.set_xlabel('Normalized Price')
ax.set_ylabel('Frequency')
ax.set_title('Normalized Prices for Each Population')
ax.legend()

# Show the plot
plt.show()

# %% [markdown]
# #### Exercise 21. Make a plot of the coordinates (latitude and longitude columns) of the south belt of Madrid by color of each population (you must use the subset obtained in the question 14) (★★★★)
#
# Execute the following cell and then start coding in the next one. You must implement a simple code that transform the coordinates columns in a Python dictionary (add more information if needed) and then add it to the map

# %%
import pandas as pd
import folium

# Create a base map
map_center = [south_belt_df['latitude'].mean(), south_belt_df['longitude'].mean()]
m = folium.Map(location=map_center, zoom_start=12)

# Create a color dictionary for each population
populations = south_belt_df['level5'].unique()
colors = ['red', 'blue', 'green', 'purple', 'orange', 'yellow']  # Add more colors if needed
color_dict = {population: colors[i % len(colors)] for i, population in enumerate(populations)}

# Add markers
for _, row in south_belt_df.iterrows():
    folium.CircleMarker(
        location=[row['latitude'], row['longitude']],
        radius=5,
        color=color_dict[row['level5']],
        fill=True,
        fill_color=color_dict[row['level5']],
        popup=row['level5']
    ).add_to(m)

# Show the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_38e22db384e7ed60518370fad9e54603 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_38e22db384e7ed60518370fad9e54603&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_38e22db384e7ed60518370fad9e54603 = L.map(
#                 &quot;map_38e22db384e7ed60518370fad9e54603&quot;,
#                 {
#                     center: [39.821435363625206, -3.7322540436748928],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4e7068d47f5ecf9a37eb6ac49cc43f75 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_4e7068d47f5ecf9a37eb6ac49cc43f75.addTo(map_38e22db384e7ed60518370fad9e54603);
#
#
#             var circle_marker_eeaadcbd08e99658cd6f19a1ee6d3b68 = L.circleMarker(
#                 [40.28674, -3.79351],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_38e22db384e7ed60518370fad9e54603);
#
#
#         var popup_68ad2b06a8085d8aa492aba1b38ad217 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_998ad68888960b472f3e710e112ffc2f = $(`&lt;div id=&quot;html_998ad68888960b472f3e710e112ffc2f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Fuenlabrada&lt;/div&gt;`)[0];
#                 popup_68ad2b06a8085d8aa492aba1b38ad217.setContent(html_998ad68888960b472f3e710e112ffc2f);
#
#
#
#         circle_marker_eeaadcbd08e99658cd6f19a1ee6d3b68.bindPopup(popup_68ad2b06a8085d8aa492aba1b38ad217)
#         ;
#
#
#
#
#             var circle_marker_ca11cc8577fdb9af71a829662fc7bf6a = L.circleMarker(
#                 [40.2853785786438, -3.79508142135624],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_38e22db384e7ed60518370fad9e54603);
#
#
#         var popup_294fbcdbe8d60df3d181c1d918acac43 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c9b23b28dde44fa7791fbe9cafb4d619 = $(`&lt;div id=&quot;html_c9b23b28dde44fa7791fbe9cafb4d619&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Fuenlabrada&lt;/div&gt;`)[0];
#                 popup_294fbcdbe8d60df3d181c1d918acac43.setContent(html_c9b23b28dde44fa7791fbe9cafb4d619);
#
#
#
#         circle_marker_ca11cc8577fdb9af71a829662fc7bf6a.bindPopup(popup_294fbcdbe8d60df3d181c1d918acac43)
#         ;
#
#
#
#
#             var circle_marker_9803058fd7c352e7c39a5c1d5776a1a7 = L.circleMarker(
#                 [40.35059, -3.82693],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_38e22db384e7ed60518370fad9e54603);
#
#
#         var popup_9470937ed1ffb1bddd142e89b194949b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4c406b9677a34aa5eab95d0a4d54453e = $(`&lt;div id=&quot;html_4c406b9677a34aa5eab95d0a4d54453e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Alcorcón&lt;/div&gt;`)[0];
#                 popup_9470937ed1ffb1bddd142e89b194949b.setContent(html_4c406b9677a34aa5eab95d0a4d54453e);
#
#
#
#         circle_marker_9803058fd7c352e7c39a5c1d5776a1a7.bindPopup(popup_9470937ed1ffb1bddd142e89b194949b)
#         ;
#
#
#
#
#             var circle_marker_a9a2cbb2b2d479243daa8c25dc5575b0 = L.circleMarker(
#                 [40.31933, -3.77574],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillO
